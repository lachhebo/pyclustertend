# %%
from sklearn.neighbors import BallTree
import numpy as np
from random import sample
from numpy.random import uniform 
import pandas as pd
D = pd.read_csv('compresive_strength_concrete.csv')

# %%
from hopkins import Hopkins
hop = Hopkins(D,200)

# %%
l = []
for i in range (0,100):
    l.append(hop.evalue())
    
np.mean(l)
# Out:
# 0.9129814310007525

# %%
l
# Out:
# [array([0.90599406]),
#  array([0.91950444]),
#  array([0.90348013]),
#  array([0.91329616]),
#  array([0.92327786]),
#  array([0.90631184]),
#  array([0.9049672]),
#  array([0.91083851]),
#  array([0.90552864]),
#  array([0.91042448]),
#  array([0.90549122]),
#  array([0.90814493]),
#  array([0.91890298]),
#  array([0.91178851]),
#  array([0.92082992]),
#  array([0.91536874]),
#  array([0.91073896]),
#  array([0.916064]),
#  array([0.91856121]),
#  array([0.91061661]),
#  array([0.91628869]),
#  array([0.90321464]),
#  array([0.91174381]),
#  array([0.90538299]),
#  array([0.91467053]),
#  array([0.9072381]),
#  array([0.91029978]),
#  array([0.92260754]),
#  array([0.90599988]),
#  array([0.91721685]),
#  array([0.91954725]),
#  array([0.91546501]),
#  array([0.91842195]),
#  array([0.91547123]),
#  array([0.90448573]),
#  array([0.91511656]),
#  array([0.91490228]),
#  array([0.91738607]),
#  array([0.91430285]),
#  array([0.9186276]),
#  array([0.92391915]),
# ...

# %%
dist, ind = tree.query(P, k=1)
#print(dist)
#print(ind)
list(np.concatenate(ind))
# Out:
# [812,
#  741,
#  322,
#  1005,
#  986,
#  83,
#  748,
#  517,
#  19,
#  242,
#  918,
#  800,
#  954,
#  906,
#  979,
#  968,
#  831,
#  165,
#  758,
#  36]

# %%
D_ = D.drop(list(np.concatenate(ind)))
D_
# Out:
#       cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 0      540.0    0.0     0.0  162.0               2.5           1040.0
# 1      540.0    0.0     0.0  162.0               2.5           1055.0
# 2      332.5  142.5     0.0  228.0               0.0            932.0
# 3      332.5  142.5     0.0  228.0               0.0            932.0
# 4      198.6  132.4     0.0  192.0               0.0            978.4
# 5      266.0  114.0     0.0  228.0               0.0            932.0
# 6      380.0   95.0     0.0  228.0               0.0            932.0
# 7      380.0   95.0     0.0  228.0               0.0            932.0
# 8      266.0  114.0     0.0  228.0               0.0            932.0
# 9      475.0    0.0     0.0  228.0               0.0            932.0
# 10     198.6  132.4     0.0  192.0               0.0            978.4
# 11     198.6  132.4     0.0  192.0               0.0            978.4
# ...

# %%
tree = BallTree(D_,leaf_size=2)
dist, ind = tree.query(P, k=2)
print(dist[:,1])
dist
# Out:
# [33.79001184 24.60370704 24.59658716 38.86       36.91372238  0.
#   8.19283223 22.10452442 90.000845   23.32303797 31.20224511  2.48251888
#  60.48115409 25.38531859 41.23833168 38.56213298 55.66087405 57.2475327
#  14.80324627 62.07448429]
# array([[33.71205274, 33.79001184],
#        [ 8.80241444, 24.60370704],
#        [18.4899973 , 24.59658716],
#        [ 0.84852814, 38.86      ],
#        [ 0.51961524, 36.91372238],
#        [ 0.        ,  0.        ],
#        [ 7.93176525,  8.19283223],
#        [ 6.57635157, 22.10452442],
#        [67.17967252, 90.000845  ],
#        [ 2.27290563, 23.32303797],
#        [ 0.6244998 , 31.20224511],
#        [ 2.4530797 ,  2.48251888],
#        [ 0.82462113, 60.48115409],
#        [ 0.94339811, 25.38531859],
#        [ 0.60835845, 41.23833168],
#        [ 0.47958315, 38.56213298],
#        [ 0.6       , 55.66087405],
#        [35.04625515, 57.2475327 ],
#        [ 8.26801064, 14.80324627],
#        [21.34461056, 62.07448429]])
